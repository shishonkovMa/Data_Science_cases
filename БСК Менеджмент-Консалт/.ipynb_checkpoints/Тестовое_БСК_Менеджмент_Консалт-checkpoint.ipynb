# %% [markdown]
# # Сеть кофеен
#
# <b>Целевой переменной выступает средний товарооборот за определенный промежуток времени (переменная «target»).</b> Данная переменная известна для обучающей выборки и неизвестна для тестовой. Для каждой кофейни даны:
#     1. Идентификатор (id).
#     2. Расстояние до метро.
#     3. Набор признаков, характеризующих окружающие кофейню объекты различных категорий в указанном радиусе относительно кофейни: количество отзывов, количество объектов, средний рейтинг объектов. В категорию «Кофейни» в данных признаках рассматриваемая кофейня не включается.
#     4. Набор признаков, характеризующих интенсивность транспортных и пешеходных потоков в указанном радиусе или пешей доступности относительно кофейни. Интенсивность рассчитана отдельно для пешеходов, автомобилей, суммы первых и вторых; для разного времени суток (утро, день, вечер, весь день); для числа сигналов и числа пользователей (юзеров); для резидентов района, в котором находится рассматриваемая кофейня, и для работников этого района.
#     5. Набор признаков, характеризующих жилые дома в указанном радиусе или пешей доступности относительно кофейни. Данные признаки рассчитываются отдельно для числа квартир и цены квадратного метра.
#     6. Набор признаков, характеризующих мобильный трафик в указанном радиусе относительно кофейни. Данные признаки рассчитываются отдельно для групп, разделенных по возрасту и доходу, а также для типов трафика для района, где расположена рассматриваемая кофейня (домашний, рабочий, транзитный, длительный, их сумма).
#     7. Набор признаков, характеризующих тип кофейни. Данная бинарная переменная определяется специфическим расположением кофейни (в бизнес-центре, в крупном транспортном узле (хаб), в любом здании кроме бизнес-центра и торгового центра (улица), в торговом центре).
#
# <b>Примечание:</b> «heaviside» и «gauss» в названиях признаков характеризуют методику расчета расстояния.
#
# <b>Задание:</b> создайте подходящую модель, наиболее точно прогнозирующую товарооборот кофеен. При создании модели рекомендуется опираться на бизнес-смысл исследуемой отрасли. Примите к сведению, что среди посетителей данной кофейни преобладают женщины. Проинтерпретируйте признаки, используемые в модели. В качестве ключевой метрики используйте MAPE (mean average percentage error). Выведите ее значение на кросс-валидации на обучающей выборке. Заполните спрогнозированными на тестовой выборке при помощи полученной модели значениями приложенную форму.
#
# <b>Формат отчета:</b> Моделирование необходимо выполнить на python. На выходе нужно предоставить jupyter_notebook / rmarkdown / аналог с понятным описанием логики построения модели и интерпретацией результатов или аналог в doc / ppt / pdf / html.

# %% [markdown]
# ## Импорт данных и библиотек
# Импортируюем данные и загрузим библиотеки

# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor, Pool
import matplotlib.pyplot as plt
# %matplotlib inline


path = os.getcwd()

for i in os.listdir():
    if 'dataset' in i:
        dataset = pd.read_excel(path + '/' + i)
    if 'форма' in i:
        form = pd.read_excel(path + '/' + i)

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Columns: 2335 entries, id to Тип ТЦ
# dtypes: float64(1182), int64(1153)
# memory usage: 1.7 MB

# %% [markdown]
# Посмотрим на хвост датасета.

# %%
dataset.tail(15)
# Out:
#      id    target  Расстояние до метро  \
# 83   94  1.557741          5123.453252
# 84   81  1.383704          3238.098609
# 85   11  1.331065         13175.266371
# 86   67  1.257284         19176.051056
# 87  131  1.225414          6303.997247
# 88    3       NaN          7306.072789
# 89   25       NaN         12907.770098
# 90   55       NaN          1856.374075
# 91   69       NaN         11166.487730
# 92  109       NaN         12697.844276
# 93  112       NaN         19887.712950
# 94  117       NaN           485.615204
# 95  126       NaN          2420.989438
# 96  144       NaN         11997.377318
# 97  145       NaN          2679.677085
#
#     Суммарное кол-во отзывов в категории "АЗС" в радиусе 150м  \
# 83                                                  0
# 84                                                  0
# 85                                                  0
# 86                                                  0
# 87                                                  0
# 88                                                  0
# 89                                                  0
# 90                                                  0
# 91                                                  0
# 92                                                  0
# 93                                                  0
# 94                                                  0
# 95                                                  0
# 96                                                  0
# 97                                                  0
#
#     Суммарное кол-во отзывов в категории "Алкомаркеты" в радиусе 150м  \
# 83                                                 12
# 84                                                 82
# 85                                                 72
# 86                                                  0
# 87                                                 27
# 88                                                 24
# 89                                                115
# 90                                                  8
# 91                                                 32
# 92                                                  0
# 93                                                  0
# 94                                               1258
# 95                                                146
# 96                                                 85
# 97                                                  0
#
#     Суммарное кол-во отзывов в категории "Аптеки" в радиусе 150м  \
# 83                                                316
# 84                                                477
# 85                                                170
# 86                                                 16
# 87                                                281
# 88                                                159
# 89                                                123
# 90                                                113
# 91                                                 97
# 92                                                 94
# 93                                                193
# 94                                                237
# 95                                                346
# 96                                                414
# 97                                                139
#
#     Суммарное кол-во отзывов в категории "Банки" в радиусе 150м  \
# 83                                                  0
# 84                                                 92
# 85                                                596
# 86                                                  0
# 87                                                135
# 88                                                  0
# 89                                                427
# 90                                                  0
# 91                                                  0
# 92                                                  0
# 93                                                 32
# 94                                                103
# 95                                                 16
# 96                                                547
# 97                                                  0
#
#     Суммарное кол-во отзывов в категории "Бизнес_центры" в радиусе 150м  \
# 83                                                  0
# 84                                                 18
# 85                                                  0
# 86                                                  0
# 87                                                  0
# 88                                             178072
# 89                                                  0
# 90                                                  0
# 91                                                  0
# 92                                                  0
# 93                                                  0
# 94                                                372
# 95                                                 20
# 96                                                  0
# 97                                                  0
#
#     Суммарное кол-во отзывов в категории "ВУЗы" в радиусе 150м  \
# 83                                                  0
# 84                                                  0
# 85                                                  0
# 86                                                  0
# 87                                                  0
# 88                                                  0
# 89                                                  0
# 90                                                  0
# 91                                                  0
# 92                                               2697
# 93                                                  0
# 94                                                 60
# 95                                                  0
# 96                                                  0
# 97                                                  0
#
#     Суммарное кол-во отзывов в категории "Вокзалы" в радиусе 150м  ...  \
# 83                                                  0              ...
# 84                                                  0              ...
# 85                                                  0              ...
# 86                                                  0              ...
# 87                                                  0              ...
# 88                                                  0              ...
# 89                                                  0              ...
# 90                                             115378              ...
# 91                                                  0              ...
# 92                                                  0              ...
# 93                                                  0              ...
# 94                                                  0              ...
# 95                                                  0              ...
# 96                                                  0              ...
# 97                                                  0              ...
#
#     Суммарный вечерний трафик сигналов рабочих в радиусе 140м  \
# 83                                                 76
# 84                                                 87
# 85                                                200
# 86                                                134
# 87                                                145
# 88                                                129
# 89                                                  3
# 90                                                  9
# 91                                                418
# 92                                                  0
# 93                                                185
# 94                                                351
# 95                                                129
# 96                                                 91
# 97                                                107
#
#     Суммарный  трафик сигналов рабочих в радиусе 140м  \
# 83                                               1468
# 84                                                963
# 85                                               1426
# 86                                               1528
# 87                                                488
# 88                                                848
# 89                                                 32
# 90                                                 38
# 91                                               1633
# 92                                                  5
# 93                                               1074
# 94                                               1529
# 95                                                437
# 96                                                309
# 97                                                670
#
#     Суммарный утренний трафик юзеров рабочих в радиусе 140м  \
# 83                                                  6
# 84                                                  6
# 85                                                  7
# 86                                                  7
# 87                                                  7
# 88                                                  2
# 89                                                  4
# 90                                                  6
# 91                                                 11
# 92                                                  1
# 93                                                  6
# 94                                                  9
# 95                                                  8
# 96                                                 10
# 97                                                  9
#
#     Суммарный дневной трафик юзеров рабочих в радиусе 140м  \
# 83                                                  6
# 84                                                  5
# 85                                                  7
# 86                                                  8
# 87                                                 10
# 88                                                  5
# 89                                                  3
# 90                                                  2
# 91                                                 13
# 92                                                  0
# 93                                                  6
# 94                                                 10
# 95                                                 10
# 96                                                 10
# 97                                                 10
#
#     Суммарный вечерний трафик юзеров рабочих в радиусе 140м  \
# 83                                                  6
# 84                                                  6
# 85                                                  6
# 86                                                  8
# 87                                                 11
# 88                                                  5
# 89                                                  2
# 90                                                  1
# 91                                                 12
# 92                                                  0
# 93                                                  7
# 94                                                 10
# 95                                                  6
# 96                                                  9
# 97                                                  6
#
#     Суммарный  трафик юзеров рабочих в радиусе 140м  Тип БЦ  Тип хаб  \
# 83                                                8       0        1
# 84                                               11       0        0
# 85                                                8       0        0
# 86                                               11       0        0
# 87                                               14       0        1
# 88                                                6       0        0
# 89                                                7       0        0
# 90                                                7       0        1
# 91                                               18       0        0
# 92                                                2       0        0
# 93                                                8       0        0
# 94                                               13       0        0
# 95                                               14       0        0
# 96                                               12       0        0
# 97                                               14       0        0
#
#     Тип улица  Тип ТЦ
# 83          0       0
# 84          1       0
# 85          0       1
# 86          0       1
# 87          0       0
# 88          0       1
# 89          0       1
# 90          0       0
# 91          0       1
# 92          1       0
# 93          0       1
# 94          1       0
# 95          1       0
# 96          1       0
# 97          1       0
#
# [15 rows x 2335 columns]

# %% [markdown]
# Теперь на форму, которую необходимо заполнить.

# %%
form
# Out:
#     id  target predicted
# 0    3               NaN
# 1   25               NaN
# 2   55               NaN
# 3   69               NaN
# 4  109               NaN
# 5  112               NaN
# 6  117               NaN
# 7  126               NaN
# 8  144               NaN
# 9  145               NaN

# %% [markdown]
# Можем заметить, что последние 10 строк (начиная с 88ой) большого датасета содержат объекты, товарооборот которых и требуется спрогнозирвать.<br>
# Также скажем, что все признаки принимают численный тип, следовательно, нет необходимости обрабатывать текстовые признаки.
#
# Посмотрим на названия столбцов для понимания, какими данными мы будем оперировать.
#
# **(Закомментировал данный код, чтобы не перегружать оперативную память)**

# %%
# for i in range(len(dataset.columns)):
#     print(i+1, ' ', dataset.columns[i])

# %% [markdown]
# Быстро пробежавшись глазами по названиям столбцов, можно ввести обобщение среди порядка 2ух с лишним тысяч признаков. Фактически у нас есть:
# - 27 категорий (АЗС, Алкомаркеты, Аптеки, Банки и т.д.). Для них известны следующие данные:
#     - Суммарное кол-во отзывов в каждой категории в радиусе 5/20/150/300/500/700/1000м
# - Суммарный  пешеходный трафик сигналов в зоне доступности 5.0 / 10.0мин
# - Суммарный  пешеходный трафик юзеров в зоне доступности 5.0 / 10.0мин
# - Суммарный  пешеходный трафик сигналов резидентов в зоне доступности 5.0 / 10.0мин
# - Суммарный  пешеходный трафик юзеров резидентов в зоне доступности 5.0 / 10.0мин
# - Суммарный  пешеходный трафик сигналов рабочих в зоне доступности 5.0 / 10.0мин
# - Суммарный  пешеходный трафик юзеров рабочих в зоне доступности 5.0 / 10.0мин

# %% [markdown]
# ## Стартовая модель
#
# Прекрасно. Какие данные у нас есть, мы увидели. Теперь предварительно обучимся на них с помощью любой модели, подходящей для задачи регрессии, чтобы создать стартовую модель, узнать ее ошибку MAPE и в дальнейшем определять значимость наших изменений в зависимости от данной ошибки.
#
# Выбор модели пал на CatBoostRegressor с минимальными гиперпараметрами.<br>
# Для этого:
# - разделим датасет по наличию таргета (помним, что начиная с 88ой строки таргет отсутствует) на 2 выборки. После этого выборку с таргетом разделим на обучающую и валидационную.
# - далее разделим все выборки на таргет и признаки.
# - создадим функцию "mean_absolute_percentage_error" для подсчета MAPE
# - создадим функцию "start_model_result" т.к. часто будем обучать стартовую модель на преобразованных данных для определения значимости изменений. На входе подаются все данные (стартовая модель, признаки обучающей выборки, таргет обучающей выборки, признаки валидационной выборки, таргет валидационной выборки). На выходе из этой функции мы будем получать ошибку MAPE стартовой модели на преобразованных данных).
# - посмотрим и интерпретируем результат
#
#
# **Однако предварительно напишем функцию стандартизации наших данных, которую будем использовать впоследствии.**

# %%
def scale(features_train, features_valid):
    scaler = StandardScaler()
    scaler_fit = scaler.fit(features_train)
    features_train_scaler = scaler_fit.transform(features_train)
    features_valid_scaler = scaler_fit.transform(features_valid)
    return features_train_scaler, features_valid_scaler

# %% [markdown]
# Теперь приступим к созданию стартовой модели.
#
# Но для начало удалим столбец, который очевидно будет вносить шум в предсказательную силу модели. Это столбец "id". (под БОЛЬШИМ вопросом, пробовал обучать модели, учитывая это предложение, и у меня выросла ошибка. Возможно нумерация id связана с порядковым открытием точек. Тем самым, чем позже открылась точка, тем лучше стало сервисное обслуживание, выросло качество продукции, и следовательно увеличился положительный отклик от клиентов и вырос товарооборот)

# %%
df_with_target = dataset[:88]
df_without_target = dataset[88:]

features = df_with_target.drop(['target'], axis = 1)
target = df_with_target['target']

features_test = df_without_target.drop(['target'], axis = 1)

features_train, features_valid, target_train, target_valid = train_test_split(features, 
                                                                              target, 
                                                                              test_size=0.2, 
#                                                                               shuffle=True,
                                                                              random_state=123)

# %% [markdown]
# Проверим правильность разделения

# %%
display(features_train.shape)
display(features_valid.shape)
display(target_train.shape)
display(target_valid.shape)
# Out:
# (70, 2334)
# (18, 2334)
# (70,)
# (18,)

# %% [markdown]
# Все верно.
#
# Теперь создадим функцию для подсчета MAPE.

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %% [markdown]
# Создадим функцию создания и обучения стартовой модели и вычисления ошибки. Запустим ее.

# %%
def start_model_result(features_train, target_train, features_valid, target_valid, verbose):
    
    if verbose == True:
        verb = 'Verbose'
    else:
        verb = 'Silent'
        
    model = CatBoostRegressor(n_estimators=200,
                          learning_rate=0.01,
                          max_depth=3, 
                          loss_function='Quantile',
                          has_time=True, 
                          logging_level=verb,
                          metric_period=100)
    model.fit(features_train, target_train, plot=False)
    
    predictions = model.predict(features_valid)
    result_mape = mean_absolute_percentage_error(target_valid, predictions)
    
    return result_mape


start_result = start_model_result(features_train, target_train, features_valid, target_valid, False)
start_result
# Out:
# 8.697924900401693

# %% [markdown]
# <b>Скор стартовой модели: 8.7</b>
#
# Получается, что в среднем наша стартовая модель ошибается на 8.7%. То есть, при товарообороте в 1млн рублей, ошибка составит +-87тыс. рублей, что довольно много. Размах 174тыс. рублей не гарантирует получение прибыли. Незапланированно можно оказаться в убытках.
#
# Теперь будем отталкиваться от данного показателя. Наша задача его уменьшить насколько это возможно.
#
# ### Как это сделать?
#
# Нужно правильным образом обработать данные (все наши признаки). Но так как их количество с лихвой перекрывает численность 2тыс. для начала необходимо определиться, какие именно признаки играют решающую роль. Есть несколько подходов:
#
# 1. Обработка пропущенных значений
# 2. Инженерия признаков
# 3. Отбор признаков
# 4. Алгоритмы Ensemble Learning
# 5. Настройка гиперпараметров
#
#
#
# #### 1. Обработка пропущенных значений и аномальных значений
#
# Поскольку у нас нет прямых зависимостей признаков, как например полная дата и день недели, осмысленно заполнить пропуски у нас возможности нет. Однако посмотрим, у каких признаков имеются пропущенные значения, возможно, это натолкнет на разумную мысль.

# %%
# %%time

l = []
for i in range(len(features.isna().columns)):
    for k in range(len(features.isna())):
        if features.isna().loc[k][i]:
            print(features.columns[i])
            l.append(features.columns[i])
            break
# Out:
# Среднее кол-во отзывов в категории "АЗС" в радиусе 150м
# Среднее кол-во отзывов в категории "Алкомаркеты" в радиусе 150м
# Среднее кол-во отзывов в категории "Аптеки" в радиусе 150м
# Среднее кол-во отзывов в категории "Банки" в радиусе 150м
# Среднее кол-во отзывов в категории "Бизнес_центры" в радиусе 150м
# Среднее кол-во отзывов в категории "ВУЗы" в радиусе 150м
# Среднее кол-во отзывов в категории "Вокзалы" в радиусе 150м
# Среднее кол-во отзывов в категории "Детскиемагазины" в радиусе 150м
# Среднее кол-во отзывов в категории "Жилыедома" в радиусе 150м
# Среднее кол-во отзывов в категории "Кино" в радиусе 150м
# Среднее кол-во отзывов в категории "Косметика" в радиусе 150м
# Среднее кол-во отзывов в категории "Кофейня" в радиусе 150м
# Среднее кол-во отзывов в категории "Метро_МЦК_ж/д" в радиусе 150м
# Среднее кол-во отзывов в категории "Общепит" в радиусе 150м
# Среднее кол-во отзывов в категории "Одеждаиобувь" в радиусе 150м
# Среднее кол-во отзывов в категории "Пекарни" в радиусе 150м
# Среднее кол-во отзывов в категории "Постаматы" в радиусе 150м
# Среднее кол-во отзывов в категории "Продукты" в радиусе 150м
# Среднее кол-во отзывов в категории "Пунктывыдачи" в радиусе 150м
# Среднее кол-во отзывов в категории "Салонысвязи" в радиусе 150м
# Среднее кол-во отзывов в категории "Сетеваякосметикаидрогери" в радиусе 150м
# Среднее кол-во отзывов в категории "Сетевыепродукты" в радиусе 150м
# Среднее кол-во отзывов в категории "Стадионы" в радиусе 150м
# Среднее кол-во отзывов в категории "ТЦ" в радиусе 150м
# Среднее кол-во отзывов в категории "Хозтоварыидом" в радиусе 150м
# Среднее кол-во отзывов в категории "Цветы" в радиусе 150м
# Среднее кол-во отзывов в категории "Электроникаибытоваятехника" в радиусе 150м
# Среднее кол-во отзывов в категории "АЗС" в радиусе 300м
# Среднее кол-во отзывов в категории "Алкомаркеты" в радиусе 300м
# Среднее кол-во отзывов в категории "Аптеки" в радиусе 300м
# Среднее кол-во отзывов в категории "Банки" в радиусе 300м
# Среднее кол-во отзывов в категории "Бизнес_центры" в радиусе 300м
# Среднее кол-во отзывов в категории "ВУЗы" в радиусе 300м
# Среднее кол-во отзывов в категории "Вокзалы" в радиусе 300м
# Среднее кол-во отзывов в категории "Детскиемагазины" в радиусе 300м
# Среднее кол-во отзывов в категории "Жилыедома" в радиусе 300м
# Среднее кол-во отзывов в категории "Кино" в радиусе 300м
# Среднее кол-во отзывов в категории "Косметика" в радиусе 300м
# Среднее кол-во отзывов в категории "Кофейня" в радиусе 300м
# Среднее кол-во отзывов в категории "Метро_МЦК_ж/д" в радиусе 300м
# Среднее кол-во отзывов в категории "Общепит" в радиусе 300м
# Среднее кол-во отзывов в категории "Одеждаиобувь" в радиусе 300м
# Среднее кол-во отзывов в категории "Пекарни" в радиусе 300м
# Среднее кол-во отзывов в категории "Постаматы" в радиусе 300м
# Среднее кол-во отзывов в категории "Продукты" в радиусе 300м
# Среднее кол-во отзывов в категории "Пунктывыдачи" в радиусе 300м
# Среднее кол-во отзывов в категории "Салонысвязи" в радиусе 300м
# Среднее кол-во отзывов в категории "Сетеваякосметикаидрогери" в радиусе 300м
# Среднее кол-во отзывов в категории "Сетевыепродукты" в радиусе 300м
# Среднее кол-во отзывов в категории "Стадионы" в радиусе 300м
# Среднее кол-во отзывов в категории "ТЦ" в радиусе 300м
# Среднее кол-во отзывов в категории "Хозтоварыидом" в радиусе 300м
# Среднее кол-во отзывов в категории "Цветы" в радиусе 300м
# Среднее кол-во отзывов в категории "Электроникаибытоваятехника" в радиусе 300м
# Среднее кол-во отзывов в категории "АЗС" в радиусе 500м
# Среднее кол-во отзывов в категории "Алкомаркеты" в радиусе 500м
# Среднее кол-во отзывов в категории "Аптеки" в радиусе 500м
# Среднее кол-во отзывов в категории "Банки" в радиусе 500м
# Среднее кол-во отзывов в категории "Бизнес_центры" в радиусе 500м
# Среднее кол-во отзывов в категории "ВУЗы" в радиусе 500м
# Среднее кол-во отзывов в категории "Вокзалы" в радиусе 500м
# Среднее кол-во отзывов в категории "Детскиемагазины" в радиусе 500м
# Среднее кол-во отзывов в категории "Жилыедома" в радиусе 500м
# Среднее кол-во отзывов в категории "Кино" в радиусе 500м
# Среднее кол-во отзывов в категории "Косметика" в радиусе 500м
# Среднее кол-во отзывов в категории "Кофейня" в радиусе 500м
# Среднее кол-во отзывов в категории "Метро_МЦК_ж/д" в радиусе 500м
# Среднее кол-во отзывов в категории "Общепит" в радиусе 500м
# Среднее кол-во отзывов в категории "Одеждаиобувь" в радиусе 500м
# Среднее кол-во отзывов в категории "Пекарни" в радиусе 500м
# Среднее кол-во отзывов в категории "Постаматы" в радиусе 500м
# Среднее кол-во отзывов в категории "Продукты" в радиусе 500м
# Среднее кол-во отзывов в категории "Пунктывыдачи" в радиусе 500м
# Среднее кол-во отзывов в категории "Салонысвязи" в радиусе 500м
# Среднее кол-во отзывов в категории "Сетеваякосметикаидрогери" в радиусе 500м
# Среднее кол-во отзывов в категории "Сетевыепродукты" в радиусе 500м
# Среднее кол-во отзывов в категории "Стадионы" в радиусе 500м
# Среднее кол-во отзывов в категории "ТЦ" в радиусе 500м
# Среднее кол-во отзывов в категории "Хозтоварыидом" в радиусе 500м
# Среднее кол-во отзывов в категории "Цветы" в радиусе 500м
# Среднее кол-во отзывов в категории "Электроникаибытоваятехника" в радиусе 500м
# Среднее кол-во отзывов в категории "АЗС" в радиусе 700м
# Среднее кол-во отзывов в категории "Алкомаркеты" в радиусе 700м
# Среднее кол-во отзывов в категории "Аптеки" в радиусе 700м
# Среднее кол-во отзывов в категории "Банки" в радиусе 700м
# Среднее кол-во отзывов в категории "Бизнес_центры" в радиусе 700м
# Среднее кол-во отзывов в категории "ВУЗы" в радиусе 700м
# Среднее кол-во отзывов в категории "Вокзалы" в радиусе 700м
# Среднее кол-во отзывов в категории "Детскиемагазины" в радиусе 700м
# Среднее кол-во отзывов в категории "Жилыедома" в радиусе 700м
# Среднее кол-во отзывов в категории "Кино" в радиусе 700м
# Среднее кол-во отзывов в категории "Косметика" в радиусе 700м
# Среднее кол-во отзывов в категории "Кофейня" в радиусе 700м
# Среднее кол-во отзывов в категории "Метро_МЦК_ж/д" в радиусе 700м
# Среднее кол-во отзывов в категории "Общепит" в радиусе 700м
# Среднее кол-во отзывов в категории "Одеждаиобувь" в радиусе 700м
# Среднее кол-во отзывов в категории "Пекарни" в радиусе 700м
# Среднее кол-во отзывов в категории "Постаматы" в радиусе 700м
# Среднее кол-во отзывов в категории "Пунктывыдачи" в радиусе 700м
# Среднее кол-во отзывов в категории "Салонысвязи" в радиусе 700м
# Среднее кол-во отзывов в категории "Сетеваякосметикаидрогери" в радиусе 700м
# Среднее кол-во отзывов в категории "Сетевыепродукты" в радиусе 700м
# Среднее кол-во отзывов в категории "Стадионы" в радиусе 700м
# Среднее кол-во отзывов в категории "ТЦ" в радиусе 700м
# Среднее кол-во отзывов в категории "Хозтоварыидом" в радиусе 700м
# Среднее кол-во отзывов в категории "Цветы" в радиусе 700м
# Среднее кол-во отзывов в категории "Электроникаибытоваятехника" в радиусе 700м
# Среднее кол-во отзывов в категории "АЗС" в радиусе 1000м
# Среднее кол-во отзывов в категории "Алкомаркеты" в радиусе 1000м
# Среднее кол-во отзывов в категории "Аптеки" в радиусе 1000м
# Среднее кол-во отзывов в категории "Банки" в радиусе 1000м
# Среднее кол-во отзывов в категории "Бизнес_центры" в радиусе 1000м
# Среднее кол-во отзывов в категории "ВУЗы" в радиусе 1000м
# Среднее кол-во отзывов в категории "Вокзалы" в радиусе 1000м
# Среднее кол-во отзывов в категории "Детскиемагазины" в радиусе 1000м
# Среднее кол-во отзывов в категории "Жилыедома" в радиусе 1000м
# Среднее кол-во отзывов в категории "Кино" в радиусе 1000м
# Среднее кол-во отзывов в категории "Косметика" в радиусе 1000м
# Среднее кол-во отзывов в категории "Кофейня" в радиусе 1000м
# Среднее кол-во отзывов в категории "Метро_МЦК_ж/д" в радиусе 1000м
# Среднее кол-во отзывов в категории "Общепит" в радиусе 1000м
# Среднее кол-во отзывов в категории "Одеждаиобувь" в радиусе 1000м
# Среднее кол-во отзывов в категории "Пекарни" в радиусе 1000м
# Среднее кол-во отзывов в категории "Постаматы" в радиусе 1000м
# Среднее кол-во отзывов в категории "Пунктывыдачи" в радиусе 1000м
# Среднее кол-во отзывов в категории "Салонысвязи" в радиусе 1000м
# Среднее кол-во отзывов в категории "Сетеваякосметикаидрогери" в радиусе 1000м
# Среднее кол-во отзывов в категории "Сетевыепродукты" в радиусе 1000м
# Среднее кол-во отзывов в категории "Стадионы" в радиусе 1000м
# Среднее кол-во отзывов в категории "ТЦ" в радиусе 1000м
# Среднее кол-во отзывов в категории "Хозтоварыидом" в радиусе 1000м
# Среднее кол-во отзывов в категории "Цветы" в радиусе 1000м
# Среднее кол-во отзывов в категории "Электроникаибытоваятехника" в радиусе 1000м
# Среднее количество объектов в категории "АЗС" в радиусе 150м
# Среднее количество объектов в категории "Алкомаркеты" в радиусе 150м
# Среднее количество объектов в категории "Аптеки" в радиусе 150м
# Среднее количество объектов в категории "Банки" в радиусе 150м
# Среднее количество объектов в категории "Бизнес_центры" в радиусе 150м
# Среднее количество объектов в категории "ВУЗы" в радиусе 150м
# Среднее количество объектов в категории "Вокзалы" в радиусе 150м
# Среднее количество объектов в категории "Детскиемагазины" в радиусе 150м
# Среднее количество объектов в категории "Жилыедома" в радиусе 150м
# Среднее количество объектов в категории "Кино" в радиусе 150м
# Среднее количество объектов в категории "Косметика" в радиусе 150м
# Среднее количество объектов в категории "Кофейня" в радиусе 150м
# Среднее количество объектов в категории "Метро_МЦК_ж/д" в радиусе 150м
# Среднее количество объектов в категории "Общепит" в радиусе 150м
# Среднее количество объектов в категории "Одеждаиобувь" в радиусе 150м
# Среднее количество объектов в категории "Пекарни" в радиусе 150м
# Среднее количество объектов в категории "Постаматы" в радиусе 150м
# Среднее количество объектов в категории "Продукты" в радиусе 150м
# Среднее количество объектов в категории "Пунктывыдачи" в радиусе 150м
# Среднее количество объектов в категории "Салонысвязи" в радиусе 150м
# Среднее количество объектов в категории "Сетеваякосметикаидрогери" в радиусе 150м
# Среднее количество объектов в категории "Сетевыепродукты" в радиусе 150м
# Среднее количество объектов в категории "Стадионы" в радиусе 150м
# Среднее количество объектов в категории "ТЦ" в радиусе 150м
# Среднее количество объектов в категории "Хозтоварыидом" в радиусе 150м
# Среднее количество объектов в категории "Цветы" в радиусе 150м
# Среднее количество объектов в категории "Электроникаибытоваятехника" в радиусе 150м
# Среднее количество объектов в категории "АЗС" в радиусе 300м
# Среднее количество объектов в категории "Алкомаркеты" в радиусе 300м
# Среднее количество объектов в категории "Аптеки" в радиусе 300м
# Среднее количество объектов в категории "Банки" в радиусе 300м
# Среднее количество объектов в категории "Бизнес_центры" в радиусе 300м
# Среднее количество объектов в категории "ВУЗы" в радиусе 300м
# Среднее количество объектов в категории "Вокзалы" в радиусе 300м
# Среднее количество объектов в категории "Детскиемагазины" в радиусе 300м
# Среднее количество объектов в категории "Жилыедома" в радиусе 300м
# Среднее количество объектов в категории "Кино" в радиусе 300м
# Среднее количество объектов в категории "Косметика" в радиусе 300м
# Среднее количество объектов в категории "Кофейня" в радиусе 300м
# Среднее количество объектов в категории "Метро_МЦК_ж/д" в радиусе 300м
# Среднее количество объектов в категории "Общепит" в радиусе 300м
# Среднее количество объектов в категории "Одеждаиобувь" в радиусе 300м
# Среднее количество объектов в категории "Пекарни" в радиусе 300м
# Среднее количество объектов в категории "Постаматы" в радиусе 300м
# Среднее количество объектов в категории "Продукты" в радиусе 300м
# Среднее количество объектов в категории "Пунктывыдачи" в радиусе 300м
# Среднее количество объектов в категории "Салонысвязи" в радиусе 300м
# Среднее количество объектов в категории "Сетеваякосметикаидрогери" в радиусе 300м
# Среднее количество объектов в категории "Сетевыепродукты" в радиусе 300м
# Среднее количество объектов в категории "Стадионы" в радиусе 300м
# Среднее количество объектов в категории "ТЦ" в радиусе 300м
# Среднее количество объектов в категории "Хозтоварыидом" в радиусе 300м
# Среднее количество объектов в категории "Цветы" в радиусе 300м
# Среднее количество объектов в категории "Электроникаибытоваятехника" в радиусе 300м
# Среднее количество объектов в категории "АЗС" в радиусе 500м
# Среднее количество объектов в категории "Алкомаркеты" в радиусе 500м
# Среднее количество объектов в категории "Аптеки" в радиусе 500м
# Среднее количество объектов в категории "Банки" в радиусе 500м
# Среднее количество объектов в категории "Бизнес_центры" в радиусе 500м
# Среднее количество объектов в категории "ВУЗы" в радиусе 500м
# Среднее количество объектов в категории "Вокзалы" в радиусе 500м
# Среднее количество объектов в категории "Детскиемагазины" в радиусе 500м
# Среднее количество объектов в категории "Жилыедома" в радиусе 500м
# Среднее количество объектов в категории "Кино" в радиусе 500м
# Среднее количество объектов в категории "Косметика" в радиусе 500м
# Среднее количество объектов в категории "Кофейня" в радиусе 500м
# Среднее количество объектов в категории "Метро_МЦК_ж/д" в радиусе 500м
# Среднее количество объектов в категории "Общепит" в радиусе 500м
# Среднее количество объектов в категории "Одеждаиобувь" в радиусе 500м
# Среднее количество объектов в категории "Пекарни" в радиусе 500м
# Среднее количество объектов в категории "Постаматы" в радиусе 500м
# Среднее количество объектов в категории "Продукты" в радиусе 500м
# Среднее количество объектов в категории "Пунктывыдачи" в радиусе 500м
# Среднее количество объектов в категории "Салонысвязи" в радиусе 500м
# Среднее количество объектов в категории "Сетеваякосметикаидрогери" в радиусе 500м
# Среднее количество объектов в категории "Сетевыепродукты" в радиусе 500м
# Среднее количество объектов в категории "Стадионы" в радиусе 500м
# Среднее количество объектов в категории "ТЦ" в радиусе 500м
# Среднее количество объектов в категории "Хозтоварыидом" в радиусе 500м
# Среднее количество объектов в категории "Цветы" в радиусе 500м
# Среднее количество объектов в категории "Электроникаибытоваятехника" в радиусе 500м
# Среднее количество объектов в категории "АЗС" в радиусе 700м
# Среднее количество объектов в категории "Алкомаркеты" в радиусе 700м
# Среднее количество объектов в категории "Аптеки" в радиусе 700м
# Среднее количество объектов в категории "Банки" в радиусе 700м
# Среднее количество объектов в категории "Бизнес_центры" в радиусе 700м
# Среднее количество объектов в категории "ВУЗы" в радиусе 700м
# Среднее количество объектов в категории "Вокзалы" в радиусе 700м
# Среднее количество объектов в категории "Детскиемагазины" в радиусе 700м
# Среднее количество объектов в категории "Жилыедома" в радиусе 700м
# Среднее количество объектов в категории "Кино" в радиусе 700м
# Среднее количество объектов в категории "Косметика" в радиусе 700м
# Среднее количество объектов в категории "Кофейня" в радиусе 700м
# Среднее количество объектов в категории "Метро_МЦК_ж/д" в радиусе 700м
# Среднее количество объектов в категории "Общепит" в радиусе 700м
# Среднее количество объектов в категории "Одеждаиобувь" в радиусе 700м
# Среднее количество объектов в категории "Пекарни" в радиусе 700м
# Среднее количество объектов в категории "Постаматы" в радиусе 700м
# Среднее количество объектов в категории "Пунктывыдачи" в радиусе 700м
# Среднее количество объектов в категории "Салонысвязи" в радиусе 700м
# Среднее количество объектов в категории "Сетеваякосметикаидрогери" в радиусе 700м
# Среднее количество объектов в категории "Сетевыепродукты" в радиусе 700м
# Среднее количество объектов в категории "Стадионы" в радиусе 700м
# Среднее количество объектов в категории "ТЦ" в радиусе 700м
# Среднее количество объектов в категории "Хозтоварыидом" в радиусе 700м
# Среднее количество объектов в категории "Цветы" в радиусе 700м
# Среднее количество объектов в категории "Электроникаибытоваятехника" в радиусе 700м
# Среднее количество объектов в категории "АЗС" в радиусе 1000м
# Среднее количество объектов в категории "Алкомаркеты" в радиусе 1000м
# Среднее количество объектов в категории "Аптеки" в радиусе 1000м
# Среднее количество объектов в категории "Банки" в радиусе 1000м
# Среднее количество объектов в категории "Бизнес_центры" в радиусе 1000м
# Среднее количество объектов в категории "ВУЗы" в радиусе 1000м
# Среднее количество объектов в категории "Вокзалы" в радиусе 1000м
# Среднее количество объектов в категории "Детскиемагазины" в радиусе 1000м
# Среднее количество объектов в категории "Жилыедома" в радиусе 1000м
# Среднее количество объектов в категории "Кино" в радиусе 1000м
# Среднее количество объектов в категории "Косметика" в радиусе 1000м
# Среднее количество объектов в категории "Кофейня" в радиусе 1000м
# Среднее количество объектов в категории "Метро_МЦК_ж/д" в радиусе 1000м
# Среднее количество объектов в категории "Общепит" в радиусе 1000м
# Среднее количество объектов в категории "Одеждаиобувь" в радиусе 1000м
# Среднее количество объектов в категории "Пекарни" в радиусе 1000м
# Среднее количество объектов в категории "Постаматы" в радиусе 1000м
# Среднее количество объектов в категории "Пунктывыдачи" в радиусе 1000м
# Среднее количество объектов в категории "Салонысвязи" в радиусе 1000м
# Среднее количество объектов в категории "Сетеваякосметикаидрогери" в радиусе 1000м
# Среднее количество объектов в категории "Сетевыепродукты" в радиусе 1000м
# Среднее количество объектов в категории "Стадионы" в радиусе 1000м
# Среднее количество объектов в категории "ТЦ" в радиусе 1000м
# Среднее количество объектов в категории "Хозтоварыидом" в радиусе 1000м
# Среднее количество объектов в категории "Цветы" в радиусе 1000м
# Среднее количество объектов в категории "Электроникаибытоваятехника" в радиусе 1000м
# Средний средний рейтинг объектов в категории "АЗС" в радиусе 150м
# Средний средний рейтинг объектов в категории "Алкомаркеты" в радиусе 150м
# Средний средний рейтинг объектов в категории "Аптеки" в радиусе 150м
# Средний средний рейтинг объектов в категории "Банки" в радиусе 150м
# Средний средний рейтинг объектов в категории "Бизнес_центры" в радиусе 150м
# Средний средний рейтинг объектов в категории "ВУЗы" в радиусе 150м
# Средний средний рейтинг объектов в категории "Вокзалы" в радиусе 150м
# Средний средний рейтинг объектов в категории "Детскиемагазины" в радиусе 150м
# Средний средний рейтинг объектов в категории "Жилыедома" в радиусе 150м
# Средний средний рейтинг объектов в категории "Кино" в радиусе 150м
# Средний средний рейтинг объектов в категории "Косметика" в радиусе 150м
# Средний средний рейтинг объектов в категории "Кофейня" в радиусе 150м
# Средний средний рейтинг объектов в категории "Метро_МЦК_ж/д" в радиусе 150м
# Средний средний рейтинг объектов в категории "Общепит" в радиусе 150м
# Средний средний рейтинг объектов в категории "Одеждаиобувь" в радиусе 150м
# Средний средний рейтинг объектов в категории "Пекарни" в радиусе 150м
# Средний средний рейтинг объектов в категории "Постаматы" в радиусе 150м
# Средний средний рейтинг объектов в категории "Продукты" в радиусе 150м
# Средний средний рейтинг объектов в категории "Пунктывыдачи" в радиусе 150м
# Средний средний рейтинг объектов в категории "Салонысвязи" в радиусе 150м
# Средний средний рейтинг объектов в категории "Сетеваякосметикаидрогери" в радиусе 150м
# Средний средний рейтинг объектов в категории "Сетевыепродукты" в радиусе 150м
# Средний средний рейтинг объектов в категории "Стадионы" в радиусе 150м
# Средний средний рейтинг объектов в категории "ТЦ" в радиусе 150м
# Средний средний рейтинг объектов в категории "Хозтоварыидом" в радиусе 150м
# Средний средний рейтинг объектов в категории "Цветы" в радиусе 150м
# Средний средний рейтинг объектов в категории "Электроникаибытоваятехника" в радиусе 150м
# Средний средний рейтинг объектов в категории "АЗС" в радиусе 300м
# Средний средний рейтинг объектов в категории "Алкомаркеты" в радиусе 300м
# Средний средний рейтинг объектов в категории "Аптеки" в радиусе 300м
# Средний средний рейтинг объектов в категории "Банки" в радиусе 300м
# Средний средний рейтинг объектов в категории "Бизнес_центры" в радиусе 300м
# Средний средний рейтинг объектов в категории "ВУЗы" в радиусе 300м
# Средний средний рейтинг объектов в категории "Вокзалы" в радиусе 300м
# Средний средний рейтинг объектов в категории "Детскиемагазины" в радиусе 300м
# Средний средний рейтинг объектов в категории "Жилыедома" в радиусе 300м
# Средний средний рейтинг объектов в категории "Кино" в радиусе 300м
# Средний средний рейтинг объектов в категории "Косметика" в радиусе 300м
# Средний средний рейтинг объектов в категории "Кофейня" в радиусе 300м
# Средний средний рейтинг объектов в категории "Метро_МЦК_ж/д" в радиусе 300м
# Средний средний рейтинг объектов в категории "Общепит" в радиусе 300м
# Средний средний рейтинг объектов в категории "Одеждаиобувь" в радиусе 300м
# Средний средний рейтинг объектов в категории "Пекарни" в радиусе 300м
# Средний средний рейтинг объектов в категории "Постаматы" в радиусе 300м
# Средний средний рейтинг объектов в категории "Продукты" в радиусе 300м
# Средний средний рейтинг объектов в категории "Пунктывыдачи" в радиусе 300м
# Средний средний рейтинг объектов в категории "Салонысвязи" в радиусе 300м
# Средний средний рейтинг объектов в категории "Сетеваякосметикаидрогери" в радиусе 300м
# Средний средний рейтинг объектов в категории "Сетевыепродукты" в радиусе 300м
# Средний средний рейтинг объектов в категории "Стадионы" в радиусе 300м
# Средний средний рейтинг объектов в категории "ТЦ" в радиусе 300м
# Средний средний рейтинг объектов в категории "Хозтоварыидом" в радиусе 300м
# Средний средний рейтинг объектов в категории "Цветы" в радиусе 300м
# Средний средний рейтинг объектов в категории "Электроникаибытоваятехника" в радиусе 300м
# Средний средний рейтинг объектов в категории "АЗС" в радиусе 500м
# Средний средний рейтинг объектов в категории "Алкомаркеты" в радиусе 500м
# Средний средний рейтинг объектов в категории "Аптеки" в радиусе 500м
# Средний средний рейтинг объектов в категории "Банки" в радиусе 500м
# Средний средний рейтинг объектов в категории "Бизнес_центры" в радиусе 500м
# Средний средний рейтинг объектов в категории "ВУЗы" в радиусе 500м
# Средний средний рейтинг объектов в категории "Вокзалы" в радиусе 500м
# Средний средний рейтинг объектов в категории "Детскиемагазины" в радиусе 500м
# Средний средний рейтинг объектов в категории "Жилыедома" в радиусе 500м
# Средний средний рейтинг объектов в категории "Кино" в радиусе 500м
# Средний средний рейтинг объектов в категории "Косметика" в радиусе 500м
# Средний средний рейтинг объектов в категории "Кофейня" в радиусе 500м
# Средний средний рейтинг объектов в категории "Метро_МЦК_ж/д" в радиусе 500м
# Средний средний рейтинг объектов в категории "Общепит" в радиусе 500м
# Средний средний рейтинг объектов в категории "Одеждаиобувь" в радиусе 500м
# Средний средний рейтинг объектов в категории "Пекарни" в радиусе 500м
# Средний средний рейтинг объектов в категории "Постаматы" в радиусе 500м
# Средний средний рейтинг объектов в категории "Продукты" в радиусе 500м
# Средний средний рейтинг объектов в категории "Пунктывыдачи" в радиусе 500м
# Средний средний рейтинг объектов в категории "Салонысвязи" в радиусе 500м
# Средний средний рейтинг объектов в категории "Сетеваякосметикаидрогери" в радиусе 500м
# Средний средний рейтинг объектов в категории "Сетевыепродукты" в радиусе 500м
# Средний средний рейтинг объектов в категории "Стадионы" в радиусе 500м
# Средний средний рейтинг объектов в категории "ТЦ" в радиусе 500м
# Средний средний рейтинг объектов в категории "Хозтоварыидом" в радиусе 500м
# Средний средний рейтинг объектов в категории "Цветы" в радиусе 500м
# Средний средний рейтинг объектов в категории "Электроникаибытоваятехника" в радиусе 500м
# Средний средний рейтинг объектов в категории "АЗС" в радиусе 700м
# Средний средний рейтинг объектов в категории "Алкомаркеты" в радиусе 700м
# Средний средний рейтинг объектов в категории "Аптеки" в радиусе 700м
# Средний средний рейтинг объектов в категории "Банки" в радиусе 700м
# Средний средний рейтинг объектов в категории "Бизнес_центры" в радиусе 700м
# Средний средний рейтинг объектов в категории "ВУЗы" в радиусе 700м
# Средний средний рейтинг объектов в категории "Вокзалы" в радиусе 700м
# Средний средний рейтинг объектов в категории "Детскиемагазины" в радиусе 700м
# Средний средний рейтинг объектов в категории "Жилыедома" в радиусе 700м
# Средний средний рейтинг объектов в категории "Кино" в радиусе 700м
# Средний средний рейтинг объектов в категории "Косметика" в радиусе 700м
# Средний средний рейтинг объектов в категории "Кофейня" в радиусе 700м
# Средний средний рейтинг объектов в категории "Метро_МЦК_ж/д" в радиусе 700м
# Средний средний рейтинг объектов в категории "Общепит" в радиусе 700м
# Средний средний рейтинг объектов в категории "Одеждаиобувь" в радиусе 700м
# Средний средний рейтинг объектов в категории "Пекарни" в радиусе 700м
# Средний средний рейтинг объектов в категории "Постаматы" в радиусе 700м
# Средний средний рейтинг объектов в категории "Пунктывыдачи" в радиусе 700м
# Средний средний рейтинг объектов в категории "Салонысвязи" в радиусе 700м
# Средний средний рейтинг объектов в категории "Сетеваякосметикаидрогери" в радиусе 700м
# Средний средний рейтинг объектов в категории "Сетевыепродукты" в радиусе 700м
# Средний средний рейтинг объектов в категории "Стадионы" в радиусе 700м
# Средний средний рейтинг объектов в категории "ТЦ" в радиусе 700м
# Средний средний рейтинг объектов в категории "Хозтоварыидом" в радиусе 700м
# Средний средний рейтинг объектов в категории "Цветы" в радиусе 700м
# Средний средний рейтинг объектов в категории "Электроникаибытоваятехника" в радиусе 700м
# Средний средний рейтинг объектов в категории "АЗС" в радиусе 1000м
# Средний средний рейтинг объектов в категории "Алкомаркеты" в радиусе 1000м
# Средний средний рейтинг объектов в категории "Аптеки" в радиусе 1000м
# Средний средний рейтинг объектов в категории "Банки" в радиусе 1000м
# Средний средний рейтинг объектов в категории "Бизнес_центры" в радиусе 1000м
# Средний средний рейтинг объектов в категории "ВУЗы" в радиусе 1000м
# Средний средний рейтинг объектов в категории "Вокзалы" в радиусе 1000м
# Средний средний рейтинг объектов в категории "Детскиемагазины" в радиусе 1000м
# Средний средний рейтинг объектов в категории "Жилыедома" в радиусе 1000м
# Средний средний рейтинг объектов в категории "Кино" в радиусе 1000м
# Средний средний рейтинг объектов в категории "Косметика" в радиусе 1000м
# Средний средний рейтинг объектов в категории "Кофейня" в радиусе 1000м
# Средний средний рейтинг объектов в категории "Метро_МЦК_ж/д" в радиусе 1000м
# Средний средний рейтинг объектов в категории "Общепит" в радиусе 1000м
# Средний средний рейтинг объектов в категории "Одеждаиобувь" в радиусе 1000м
# Средний средний рейтинг объектов в категории "Пекарни" в радиусе 1000м
# Средний средний рейтинг объектов в категории "Постаматы" в радиусе 1000м
# Средний средний рейтинг объектов в категории "Пунктывыдачи" в радиусе 1000м
# Средний средний рейтинг объектов в категории "Салонысвязи" в радиусе 1000м
# Средний средний рейтинг объектов в категории "Сетеваякосметикаидрогери" в радиусе 1000м
# Средний средний рейтинг объектов в категории "Сетевыепродукты" в радиусе 1000м
# Средний средний рейтинг объектов в категории "Стадионы" в радиусе 1000м
# Средний средний рейтинг объектов в категории "ТЦ" в радиусе 1000м
# Средний средний рейтинг объектов в категории "Хозтоварыидом" в радиусе 1000м
# Средний средний рейтинг объектов в категории "Цветы" в радиусе 1000м
# Средний средний рейтинг объектов в категории "Электроникаибытоваятехника" в радиусе 1000м
# Среднее кол-во отзывов в категории "АЗС" в радиусе 5м
# Среднее кол-во отзывов в категории "Алкомаркеты" в радиусе 5м
# Среднее кол-во отзывов в категории "Аптеки" в радиусе 5м
# Среднее кол-во отзывов в категории "Банки" в радиусе 5м
# Среднее кол-во отзывов в категории "Бизнес_центры" в радиусе 5м
# Среднее кол-во отзывов в категории "ВУЗы" в радиусе 5м
# Среднее кол-во отзывов в категории "Вокзалы" в радиусе 5м
# Среднее кол-во отзывов в категории "Детскиемагазины" в радиусе 5м
# Среднее кол-во отзывов в категории "Жилыедома" в радиусе 5м
# Среднее кол-во отзывов в категории "Кино" в радиусе 5м
# Среднее кол-во отзывов в категории "Косметика" в радиусе 5м
# Среднее кол-во отзывов в категории "Кофейня" в радиусе 5м
# Среднее кол-во отзывов в категории "Метро_МЦК_ж/д" в радиусе 5м
# Среднее кол-во отзывов в категории "Общепит" в радиусе 5м
# Среднее кол-во отзывов в категории "Одеждаиобувь" в радиусе 5м
# Среднее кол-во отзывов в категории "Пекарни" в радиусе 5м
# Среднее кол-во отзывов в категории "Постаматы" в радиусе 5м
# Среднее кол-во отзывов в категории "Продукты" в радиусе 5м
# Среднее кол-во отзывов в категории "Пунктывыдачи" в радиусе 5м
# Среднее кол-во отзывов в категории "Салонысвязи" в радиусе 5м
# Среднее кол-во отзывов в категории "Сетеваякосметикаидрогери" в радиусе 5м
# Среднее кол-во отзывов в категории "Сетевыепродукты" в радиусе 5м
# Среднее кол-во отзывов в категории "Стадионы" в радиусе 5м
# Среднее кол-во отзывов в категории "ТЦ" в радиусе 5м
# Среднее кол-во отзывов в категории "Хозтоварыидом" в радиусе 5м
# Среднее кол-во отзывов в категории "Цветы" в радиусе 5м
# Среднее кол-во отзывов в категории "Электроникаибытоваятехника" в радиусе 5м
# Среднее кол-во отзывов в категории "АЗС" в радиусе 20м
# Среднее кол-во отзывов в категории "Алкомаркеты" в радиусе 20м
# Среднее кол-во отзывов в категории "Аптеки" в радиусе 20м
# Среднее кол-во отзывов в категории "Банки" в радиусе 20м
# Среднее кол-во отзывов в категории "Бизнес_центры" в радиусе 20м
# Среднее кол-во отзывов в категории "ВУЗы" в радиусе 20м
# Среднее кол-во отзывов в категории "Вокзалы" в радиусе 20м
# Среднее кол-во отзывов в категории "Детскиемагазины" в радиусе 20м
# Среднее кол-во отзывов в категории "Жилыедома" в радиусе 20м
# Среднее кол-во отзывов в категории "Кино" в радиусе 20м
# Среднее кол-во отзывов в категории "Косметика" в радиусе 20м
# Среднее кол-во отзывов в категории "Кофейня" в радиусе 20м
# Среднее кол-во отзывов в категории "Метро_МЦК_ж/д" в радиусе 20м
# Среднее кол-во отзывов в категории "Общепит" в радиусе 20м
# Среднее кол-во отзывов в категории "Одеждаиобувь" в радиусе 20м
# Среднее кол-во отзывов в категории "Пекарни" в радиусе 20м
# Среднее кол-во отзывов в категории "Постаматы" в радиусе 20м
# Среднее кол-во отзывов в категории "Продукты" в радиусе 20м
# Среднее кол-во отзывов в категории "Пунктывыдачи" в радиусе 20м
# Среднее кол-во отзывов в категории "Салонысвязи" в радиусе 20м
# Среднее кол-во отзывов в категории "Сетеваякосметикаидрогери" в радиусе 20м
# Среднее кол-во отзывов в категории "Сетевыепродукты" в радиусе 20м
# Среднее кол-во отзывов в категории "Стадионы" в радиусе 20м
# Среднее кол-во отзывов в категории "ТЦ" в радиусе 20м
# Среднее кол-во отзывов в категории "Хозтоварыидом" в радиусе 20м
# Среднее кол-во отзывов в категории "Цветы" в радиусе 20м
# Среднее кол-во отзывов в категории "Электроникаибытоваятехника" в радиусе 20м
# Среднее количество объектов в категории "АЗС" в радиусе 5м
# Среднее количество объектов в категории "Алкомаркеты" в радиусе 5м
# Среднее количество объектов в категории "Аптеки" в радиусе 5м
# Среднее количество объектов в категории "Банки" в радиусе 5м
# Среднее количество объектов в категории "Бизнес_центры" в радиусе 5м
# Среднее количество объектов в категории "ВУЗы" в радиусе 5м
# Среднее количество объектов в категории "Вокзалы" в радиусе 5м
# Среднее количество объектов в категории "Детскиемагазины" в радиусе 5м
# Среднее количество объектов в категории "Жилыедома" в радиусе 5м
# Среднее количество объектов в категории "Кино" в радиусе 5м
# Среднее количество объектов в категории "Косметика" в радиусе 5м
# Среднее количество объектов в категории "Кофейня" в радиусе 5м
# Среднее количество объектов в категории "Метро_МЦК_ж/д" в радиусе 5м
# Среднее количество объектов в категории "Общепит" в радиусе 5м
# Среднее количество объектов в категории "Одеждаиобувь" в радиусе 5м
# Среднее количество объектов в категории "Пекарни" в радиусе 5м
# Среднее количество объектов в категории "Постаматы" в радиусе 5м
# Среднее количество объектов в категории "Продукты" в радиусе 5м
# Среднее количество объектов в категории "Пунктывыдачи" в радиусе 5м
# Среднее количество объектов в категории "Салонысвязи" в радиусе 5м
# Среднее количество объектов в категории "Сетеваякосметикаидрогери" в радиусе 5м
# Среднее количество объектов в категории "Сетевыепродукты" в радиусе 5м
# Среднее количество объектов в категории "Стадионы" в радиусе 5м
# Среднее количество объектов в категории "ТЦ" в радиусе 5м
# Среднее количество объектов в категории "Хозтоварыидом" в радиусе 5м
# Среднее количество объектов в категории "Цветы" в радиусе 5м
# Среднее количество объектов в категории "Электроникаибытоваятехника" в радиусе 5м
# Среднее количество объектов в категории "АЗС" в радиусе 20м
# Среднее количество объектов в категории "Алкомаркеты" в радиусе 20м
# Среднее количество объектов в категории "Аптеки" в радиусе 20м
# Среднее количество объектов в категории "Банки" в радиусе 20м
# Среднее количество объектов в категории "Бизнес_центры" в радиусе 20м
# Среднее количество объектов в категории "ВУЗы" в радиусе 20м
# Среднее количество объектов в категории "Вокзалы" в радиусе 20м
# Среднее количество объектов в категории "Детскиемагазины" в радиусе 20м
# Среднее количество объектов в категории "Жилыедома" в радиусе 20м
# Среднее количество объектов в категории "Кино" в радиусе 20м
# Среднее количество объектов в категории "Косметика" в радиусе 20м
# Среднее количество объектов в категории "Кофейня" в радиусе 20м
# Среднее количество объектов в категории "Метро_МЦК_ж/д" в радиусе 20м
# Среднее количество объектов в категории "Общепит" в радиусе 20м
# Среднее количество объектов в категории "Одеждаиобувь" в радиусе 20м
# Среднее количество объектов в категории "Пекарни" в радиусе 20м
# Среднее количество объектов в категории "Постаматы" в радиусе 20м
# Среднее количество объектов в категории "Продукты" в радиусе 20м
# Среднее количество объектов в категории "Пунктывыдачи" в радиусе 20м
# Среднее количество объектов в категории "Салонысвязи" в радиусе 20м
# Среднее количество объектов в категории "Сетеваякосметикаидрогери" в радиусе 20м
# Среднее количество объектов в категории "Сетевыепродукты" в радиусе 20м
# Среднее количество объектов в категории "Стадионы" в радиусе 20м
# Среднее количество объектов в категории "ТЦ" в радиусе 20м
# Среднее количество объектов в категории "Хозтоварыидом" в радиусе 20м
# Среднее количество объектов в категории "Цветы" в радиусе 20м
# Среднее количество объектов в категории "Электроникаибытоваятехника" в радиусе 20м
# Средний средний рейтинг объектов в категории "АЗС" в радиусе 5м
# Средний средний рейтинг объектов в категории "Алкомаркеты" в радиусе 5м
# Средний средний рейтинг объектов в категории "Аптеки" в радиусе 5м
# Средний средний рейтинг объектов в категории "Банки" в радиусе 5м
# Средний средний рейтинг объектов в категории "Бизнес_центры" в радиусе 5м
# Средний средний рейтинг объектов в категории "ВУЗы" в радиусе 5м
# Средний средний рейтинг объектов в категории "Вокзалы" в радиусе 5м
# Средний средний рейтинг объектов в категории "Детскиемагазины" в радиусе 5м
# Средний средний рейтинг объектов в категории "Жилыедома" в радиусе 5м
# Средний средний рейтинг объектов в категории "Кино" в радиусе 5м
# Средний средний рейтинг объектов в категории "Косметика" в радиусе 5м
# Средний средний рейтинг объектов в категории "Кофейня" в радиусе 5м
# Средний средний рейтинг объектов в категории "Метро_МЦК_ж/д" в радиусе 5м
# Средний средний рейтинг объектов в категории "Общепит" в радиусе 5м
# Средний средний рейтинг объектов в категории "Одеждаиобувь" в радиусе 5м
# Средний средний рейтинг объектов в категории "Пекарни" в радиусе 5м
# Средний средний рейтинг объектов в категории "Постаматы" в радиусе 5м
# Средний средний рейтинг объектов в категории "Продукты" в радиусе 5м
# Средний средний рейтинг объектов в категории "Пунктывыдачи" в радиусе 5м
# Средний средний рейтинг объектов в категории "Салонысвязи" в радиусе 5м
# Средний средний рейтинг объектов в категории "Сетеваякосметикаидрогери" в радиусе 5м
# Средний средний рейтинг объектов в категории "Сетевыепродукты" в радиусе 5м
# Средний средний рейтинг объектов в категории "Стадионы" в радиусе 5м
# Средний средний рейтинг объектов в категории "ТЦ" в радиусе 5м
# Средний средний рейтинг объектов в категории "Хозтоварыидом" в радиусе 5м
# Средний средний рейтинг объектов в категории "Цветы" в радиусе 5м
# Средний средний рейтинг объектов в категории "Электроникаибытоваятехника" в радиусе 5м
# Средний средний рейтинг объектов в категории "АЗС" в радиусе 20м
# Средний средний рейтинг объектов в категории "Алкомаркеты" в радиусе 20м
# Средний средний рейтинг объектов в категории "Аптеки" в радиусе 20м
# Средний средний рейтинг объектов в категории "Банки" в радиусе 20м
# Средний средний рейтинг объектов в категории "Бизнес_центры" в радиусе 20м
# Средний средний рейтинг объектов в категории "ВУЗы" в радиусе 20м
# Средний средний рейтинг объектов в категории "Вокзалы" в радиусе 20м
# Средний средний рейтинг объектов в категории "Детскиемагазины" в радиусе 20м
# Средний средний рейтинг объектов в категории "Жилыедома" в радиусе 20м
# Средний средний рейтинг объектов в категории "Кино" в радиусе 20м
# Средний средний рейтинг объектов в категории "Косметика" в радиусе 20м
# Средний средний рейтинг объектов в категории "Кофейня" в радиусе 20м
# Средний средний рейтинг объектов в категории "Метро_МЦК_ж/д" в радиусе 20м
# Средний средний рейтинг объектов в категории "Общепит" в радиусе 20м
# Средний средний рейтинг объектов в категории "Одеждаиобувь" в радиусе 20м
# Средний средний рейтинг объектов в категории "Пекарни" в радиусе 20м
# Средний средний рейтинг объектов в категории "Постаматы" в радиусе 20м
# Средний средний рейтинг объектов в категории "Продукты" в радиусе 20м
# Средний средний рейтинг объектов в категории "Пунктывыдачи" в радиусе 20м
# Средний средний рейтинг объектов в категории "Салонысвязи" в радиусе 20м
# Средний средний рейтинг объектов в категории "Сетеваякосметикаидрогери" в радиусе 20м
# Средний средний рейтинг объектов в категории "Сетевыепродукты" в радиусе 20м
# Средний средний рейтинг объектов в категории "Стадионы" в радиусе 20м
# Средний средний рейтинг объектов в категории "ТЦ" в радиусе 20м
# Средний средний рейтинг объектов в категории "Хозтоварыидом" в радиусе 20м
# Средний средний рейтинг объектов в категории "Цветы" в радиусе 20м
# Средний средний рейтинг объектов в категории "Электроникаибытоваятехника" в радиусе 20м
# Среднее кол-во отзывов в радиусе 5м
# Среднее кол-во отзывов в радиусе 20м
# Среднее количество объектов в радиусе 5м
# Среднее количество объектов в радиусе 20м
# Средний средний рейтинг объектов в радиусе 5м
# Средний средний рейтинг объектов в радиусе 20м
# Средняя цена квадратного метра в радиусе 150м heaviside
# Средняя цена квадратного метра в радиусе 300м heaviside
# Средняя цена квадратного метра в радиусе 500м heaviside
# Средняя цена квадратного метра в радиусе 700м heaviside
# Средняя цена квадратного метра в радиусе 1000м heaviside
# Максимальный утренний автомобильный трафик сигналов резидентов в радиусе 150м
# Максимальный дневной автомобильный трафик сигналов резидентов в радиусе 150м
# Максимальный вечерний автомобильный трафик сигналов резидентов в радиусе 150м
# Максимальный утренний пешеходный трафик сигналов резидентов в радиусе 150м
# Максимальный дневной пешеходный трафик сигналов резидентов в радиусе 150м
# Максимальный вечерний пешеходный трафик сигналов резидентов в радиусе 150м
# Максимальный  автомобильный трафик сигналов резидентов в радиусе 150м
# Максимальный  пешеходный трафик сигналов резидентов в радиусе 150м
# Максимальный дневной автомобильный трафик сигналов резидентов в радиусе 300м
# Максимальный вечерний автомобильный трафик сигналов резидентов в радиусе 300м
# Средний утренний автомобильный трафик сигналов резидентов в радиусе 150м
# Средний дневной автомобильный трафик сигналов резидентов в радиусе 150м
# Средний вечерний автомобильный трафик сигналов резидентов в радиусе 150м
# Средний утренний пешеходный трафик сигналов резидентов в радиусе 150м
# Средний дневной пешеходный трафик сигналов резидентов в радиусе 150м
# Средний вечерний пешеходный трафик сигналов резидентов в радиусе 150м
# Средний  автомобильный трафик сигналов резидентов в радиусе 150м
# Средний  пешеходный трафик сигналов резидентов в радиусе 150м
# Средний дневной автомобильный трафик сигналов резидентов в радиусе 300м
# Средний вечерний автомобильный трафик сигналов резидентов в радиусе 300м
# Максимальный утренний автомобильный трафик юзеров резидентов в радиусе 150м
# Максимальный дневной автомобильный трафик юзеров резидентов в радиусе 150м
# Максимальный вечерний автомобильный трафик юзеров резидентов в радиусе 150м
# Максимальный утренний пешеходный трафик юзеров резидентов в радиусе 150м
# Максимальный дневной пешеходный трафик юзеров резидентов в радиусе 150м
# Максимальный вечерний пешеходный трафик юзеров резидентов в радиусе 150м
# Максимальный  автомобильный трафик юзеров резидентов в радиусе 150м
# Максимальный  пешеходный трафик юзеров резидентов в радиусе 150м
# Максимальный дневной автомобильный трафик юзеров резидентов в радиусе 300м
# Максимальный вечерний автомобильный трафик юзеров резидентов в радиусе 300м
# Средний дневной пешеходный трафик сигналов рабочих в радиусе 140м
# Средний вечерний пешеходный трафик сигналов рабочих в радиусе 140м
# Средний  автомобильный трафик сигналов рабочих в радиусе 140м
# Средний  пешеходный трафик сигналов рабочих в радиусе 140м
# Максимальный утренний автомобильный трафик юзеров рабочих в радиусе 140м
# Максимальный дневной автомобильный трафик юзеров рабочих в радиусе 140м
# Максимальный вечерний автомобильный трафик юзеров рабочих в радиусе 140м
# Максимальный утренний пешеходный трафик юзеров рабочих в радиусе 140м
# Максимальный дневной пешеходный трафик юзеров рабочих в радиусе 140м
# Максимальный вечерний пешеходный трафик юзеров рабочих в радиусе 140м
# Максимальный  автомобильный трафик юзеров рабочих в радиусе 140м
# Максимальный  пешеходный трафик юзеров рабочих в радиусе 140м
# Средний утренний автомобильный трафик юзеров рабочих в радиусе 140м
# Средний дневной автомобильный трафик юзеров рабочих в радиусе 140м
# Средний вечерний автомобильный трафик юзеров рабочих в радиусе 140м
# Средний утренний пешеходный трафик юзеров рабочих в радиусе 140м
# Средний дневной пешеходный трафик юзеров рабочих в радиусе 140м
# Средний вечерний пешеходный трафик юзеров рабочих в радиусе 140м
# Средний  автомобильный трафик юзеров рабочих в радиусе 140м
# Средний  пешеходный трафик юзеров рабочих в радиусе 140м
# CPU times: user 1min 7s, sys: 96.6 ms, total: 1min 7s
# Wall time: 1min 7s

# %% [markdown]
# По результатам мы видим, что пропущенные значения содержатся в столбцах:
# - "Среднее кол-во отзывов в категории..."
# - "Среднее количество объектов в категории..."
# - "Средний средний рейтинг объектов в категории..."
# - "Среднее кол-во отзывов в радиусе 5м и 20м"
# - "Среднее количество объектов в радиусе 5м и 20м"
# - "Средний средний рейтинг объектов в радиусе 5м и 20м"
# - "Средняя цена квадратного метра в радиусе..."
# - "Максимальный утренний/дневной/вечерний/общий автомобильный/пешеходный трафик..."
# - "Средний утренний/дневной/вечерний/общий автомобильный/пешеходный трафик..."
#
# <b>Как это возможно объяснить?</b>
# <br>
# <br>
# Как мы видим, большая часть пропущенных значений приходится именно на признаки со словом "Средний". Дело может быть в том, что отсутствуют параметры объектов для усреднения. То есть, например, в случае признака "Среднее кол-во отзывов в радиусе 5м" количество отзывов во всех учитывающихся заведениях равно 0. Следовательно, чтобы найти среднее количество отзывов, нам необходимо поделить сумму количества отзывов (которая равна 0) на количество этих заведений (которое также равно 0). Получается, что мы 0 делим на 0. А по правилам математики такое невозможно, поэтому и получаем ошибку, а как следствие пропущенное значение.<br>
# Логичный вариант заполнить такой пропуск - поставить 0. Так как среднее значение действительно равняется нулю.
# <br>
# <br>
# В случае же с признаком "Максимальный утренний/дневной/вечерний/общий автомобильный/пешеходный трафик..." - объяснение поддается с трудом. Можно предположить, что регистрирующие приборы не зафиксировали полученные данные, либо возникли проблемы с выгрузкой данных, где и были утеряны. Удалить такие признаки может оказаться ошибкой, поскольку они напрямую связаны с выручкой (условно: чем больше людей проходит около кофейни, тем чаще покупается кофе), однако есть догадка, что данные признаки коррелируют с усредненными признаками данной категории. Так например, может оказаться, что максимальный утренний трафик коррелирует с усредненным трафиком. Мы это проверим чуть ниже, когда будем производить отбор признаков - 3ий пункт. А пока опираясь на данную догадку о высокой корреляции, удалим эти признаки (так как нам все равно необходимо избавиться от сильных корреляций, чтобы произошло адекватное обучение модели) и посмотрим на результат.
# <br>
# <br>
# <br>
# Итак, порядок действий следующий:
# - удаляем признаки "Максимальный утренний/дневной/вечерний/общий автомобильный/пешеходный трафик..." (в предыдущей ячейке мы уже сохранили список с названиями признаков, в которых находятся пропущенные значения. Теперь осталось отфильтровать значения по вхождению слова "Максимальный" и удалить такие признаки из создаваемого нами датафрейма)
# - остальные пропущенные значения заменяем на ноль.
#
# Чтобы проверить наши действия локально и не перезаписать переменные, создадим копию переменной "features".

# %%
features_missing = features.copy()

for i in range(len(l)):
    if l[i].split(' ')[0] == "Максимальный":
        features_missing = features_missing.drop([l[i]], axis=1)

features_missing = features_missing.fillna(0)

# %% [markdown]
# Теперь обучимся на этих данных, и посмотрим результат наших действий.

# %%
features_train_missing, features_valid_missing = train_test_split(features_missing, 
                                                                  test_size=0.2, 
#                                                                   shuffle=True,
                                                                  random_state=123)

start_model_result(features_train_missing, target_train, features_valid_missing, target_valid, True)
# Out:
# 0:	learn: 0.0684695	total: 23.4ms	remaining: 4.65s
# 100:	learn: 0.0532420	total: 1.79s	remaining: 1.76s
# 199:	learn: 0.0453541	total: 3.54s	remaining: 0us
# 8.592039029587506

# %% [markdown]
# Благодаря нашим действиям мы уменьшили ошибку на 0.1.<br>
# В разрезе 1го миллиона рублей, размах ошибки у нас сократился на 2 тыс. рублей.<br>
# Стало немного лучше.<br>
# <br>
# Теперь поработаем над аномальными значениями.<br>
# В наших данных могут находится аномально высокие или аномально низкие значения признаков. Это может отражаться на обучении модели - итоговые правила моделирования будут неправильно сформированы. Однако мы не можем вопспользоваться данным инструментом, т.к. у нас очень мало объектов для обучения - всего 90 кофеин. И если мы будем удалять их по параметру аномальности наших признаков, в конечном итоге не на чем будет обучать нашу модель.<br>
# Поэтому переходим к следующему методу.

# %% [markdown]
# #### 2. Инженерия признаков

# %% [markdown]
# Есть идея скомпоновать множество признаков, в которых учитываются расстояния, например:
# - Суммарный мобильный трафик ... в радиусе 150м
# - Суммарный мобильный трафик ... в радиусе 300м
# - Суммарный мобильный трафик ... в радиусе 500м
# - Суммарный мобильный трафик ... в радиусе 700м
# - Суммарный мобильный трафик ... в радиусе 1000м
#
# Так как мы знаем, что чем ближе проходил человек к кофейне, тем больше шансов, что он ее увидел, тем больше шансов, что он в нее зашел, а следовательно, выше вероятность продажи очередной чашки кофе.
#
# Исходя из этого, мы можем составить правило, которое будет поощрять за близость и "наказывать" за удаленность. Например, первое, что приходит на ум, мы можем просуммировать данные признаки, предварительно каждый из них умножив на коэффициент так называемого "поощрения", который высчитывается по формуле:
# $$
# k = 1/удаленность
# $$
#
# Получается, что чем дальше, находится человек, тем меньше коэффициент, и наоборот.
# Итоговая формула будет выглядеть следующим образом:
#
# $$
# Модифицированный\_трафик =
# $$
# $$
# = Суммарный\_мобильный\_трафик ... в\_радиусе\_150м * 1 / 150 +
# $$
# $$
# + Суммарный\_мобильный\_трафик ... в\_радиусе\_300м * 1 / 300 +
# $$
# $$
# +Суммарный\_мобильный\_трафик ... в\_радиусе\_500м * 1 / 500 +
# $$
# $$
# +Суммарный\_мобильный\_трафик ... в\_радиусе\_700м * 1 / 700 +
# $$
# $$
# +Суммарный\_мобильный\_трафик ... в\_радиусе\_1000м * 1 / 1000
# $$
#
#
# Или можно принять во внимание какую-нибудь другую идею.<br>
# Так как это довольно трудоемкая задача, оставим ее прозапас, как дополнительную возможность улучшить нашу модель. А пока перейдем к следующему пункту.

# %% [markdown]
# #### 3. Отбор признаков
#
# Поскольку у нас довольно много признаков (свыше 2тыс.), нам необходимо понять, какие именно определяют зависимую переменную "target". Для этого есть несколько способов:
# 1. Отчистка от сильнокоррелирующих признаков
# 2. Удаление признаков, в которых очень много нулевых значений
# 3. Уменьшение размерности
# 4. Важность признаков
#
#
# ##### 3.1. Очистка от сильнокоррелирующих признаков

# %% [markdown]
# Первое, что мы применим - отчистка данных от сильнокоррелирующих признаков.<br>
# Построить график корреляций не представляется возможным,т.к. в датафрейме более 2 тыс. признаков.<br>
# Поэтому напишем функцию, которая будет принимать на вход весь датафрейм (все объекты с таргетом), таргет и границу, выше которой корреляция будет считаться высокой (в нашем случае возьмем для начала 0.9). Тем самым функция должна проверить все пары признаков на значение корреляции, и если она будет выше 0.9, то из этой пары удаляется признак, который меньше всего "определяет" нашу зависимую переменную "target". На выходе функции получим датафрейм с признаками, которые коррелируют меньше, чем значение 0.9.

# %%
def remove_collinear_features(df, target_var, threshold):
    df_model = df.copy()
    corr_matrix = df_model.drop(target_var, 1).corr()
    iters = range(len(corr_matrix.columns) - 1)
    drop_cols = []

    for i in iters:
        for j in range(i+1): 
            item = corr_matrix.iloc[j:(j+1), (i+1):(i+2)]
            col = item.columns
            row = item.index
            val = abs(item.values)

            if val >= threshold:
                col_value_corr = df_model[col.values[0]].corr(df_model[target_var])
                row_value_corr = df_model[row.values[0]].corr(df_model[target_var])
                if col_value_corr < row_value_corr:
                    drop_cols.append(col.values[0])
                else:
                    drop_cols.append(row.values[0])

    drops = set(drop_cols)
    df_model = df_model.drop(columns=drops)
    df_model = df_model.drop(['target'], axis=1)

    return df_model

# %%
# %%time

features_corr = remove_collinear_features(df_with_target, 'target', 0.9)
# Out:
# <ipython-input-13-4e6b7af3ba24>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   corr_matrix = df_model.drop(target_var, 1).corr()
# CPU times: user 4min 29s, sys: 114 ms, total: 4min 29s
# Wall time: 4min 29s

# %% [markdown]
# Почти 5 минут. Мы отчистили данные от сильнокоррелирующих признаков. Посмотрим, как это сказалось на нашей модели.
#
# Так как мы запускали на всей выборке (не включающей прогнозируемые объекты), нам повторно необходимо разделить на обучающую и валидационную. Сделаем это и повторно запустим стартовую модель.

# %%
features_train_corr, features_valid_corr = train_test_split(features_corr, 
                                                                  test_size=0.2, 
#                                                                   shuffle=True,
                                                                  random_state=123)

start_model_result(features_train_corr, target_train, features_valid_corr, target_valid, True)
# Out:
# 0:	learn: 0.0687360	total: 1.83ms	remaining: 365ms
# 100:	learn: 0.0621144	total: 94.8ms	remaining: 93ms
# 199:	learn: 0.0572830	total: 200ms	remaining: 0us
# 9.191306287768777

# %% [markdown]
# <b>Скор: 9.191306287768777</b>
#
# Средняя относительная ошибка выросла. Это означает, что мы удалили те признаки, которые определяли наш таргет. Попробуем брать другие значения.
#
# Для удобства напишем функцию.

# %%
def func_in_func(remove_collinear_features, param):
    global df_with_target
    features_corr = remove_collinear_features(df_with_target, 'target', param)
    features_train_corr, features_valid_corr = train_test_split(features_corr, 
                                                                  test_size=0.2, 
#                                                                   shuffle=True,
                                                                  random_state=123)
    res = start_model_result(features_train_corr, target_train, features_valid_corr, target_valid, True)
    return res

# %% [markdown]
# Я закомментировал код в нижеследующей ячейке в целях экономии времени.<br>
#
# Ни один из перебранных порогов корреляции не дает меньшую ошибку. Это означает, что золотая середина где-то около 0.9.
#
# А так как ошибка при 0.9 не является меньшей в нашем исследовании, брать в учет этот метод мы не будем.

# %%
# %%time

# error_remove_corr = []
# for i in [0.7, 0.75, 0.8, 0.85, 0.95]:
#     error_remove_corr.append(func_in_func(remove_collinear_features, i))
# error_remove_corr

# %% [markdown]
# ##### 3.2 Удаление признаков, в которых очень много нулевых значений.
#
# Так как удаление сильнокоррелирующих признаков не дало ощутимых улучшений, скорее только ухудшило положение дел, мы попробуем следующий подход: удаление признаков, в которых много нулевых значений. Для начала попробуем удалить признаки, в которых более 70% составляют нулевые значения. Для этого напишем функцию.
#
# При этом помним, что последние 4 признака - категориальные (распределение по типу здания: БЦ, хаб, улица, ТЦ), разделенные техникой "one hot encoding". В том числе тут присутствует переменная-ловушка: если мы знаем 3 класса, и у объекта они отстутствуют - логично предположить, что объект является 4ым. Возникает сильная корреляция. Необходимо избавиться от нее, для этого просто удалим признак "БЦ".

# %%
def features_clearing(dataset, procent):
    dataset_new = dataset.copy()
    for i in range(len(dataset.columns)-3):
        count = 0
        for k in range(len(dataset)):
            if dataset.loc[k, dataset.columns[i]] == 0:
                count +=1
        total = count / len(dataset) * 100
        if total > procent:
            dataset_new = dataset_new.drop([dataset.columns[i]], axis=1)
    return dataset_new


def func_in_func_clearing(features_clearing, param):
    features_clear = features_clearing(features_missing, param)
    features_train_clear, features_valid_clear = train_test_split(features_clear, 
                                                                  test_size=0.2, 
#                                                                   shuffle=True,
                                                                  random_state=123)

    res = start_model_result(features_train_clear, target_train, features_valid_clear, target_valid, False)
    return res

# %% [markdown]
# Узнаем, при каком проценте удаления нулевых значений, мы получим наименьшую ошибку.<br>
# Для этого запустим функцию "func_in_func_clearing" в цикле.

# %%
# %%time

error = []
for i in range(50,95,2):
    error.append(func_in_func_clearing(features_clearing, i))
# Out:
# CPU times: user 5min 54s, sys: 5.64 s, total: 6min
# Wall time: 2min 29s

# %% [markdown]
# Для визуального результата построим график.

# %%
step = [i for i in range(50,95,2)]
plt.plot(step, error, 'r')
plt.ylabel('Ошибка MAPE')
plt.xlabel('Процент нулевых значения')
plt.show()

# %% [markdown]
# Видим, что при удалении признаков с процентом нулевых значений около 70% и около 90% дают наименьшую ошибку.<br>
# Однако, это все равно не является положительным результатом, т.к. даже такая ошибка выше лучшего скора, который мы получили при обработке пропущенных значений.<br>
# Используем метод уменьшения размерности.

# %% [markdown]
# ##### 3.3 Уменьшение размерности.
#
# Уменьшение размерности уменьшает общее количество признков, это также помогает уменьшить вычислительные требования, связанные с обучением модели, и помогает бороться с переобучением, сохраняя признаки, которые будут подаваться в модель, достаточно простыми.
#
# Основными алгоритмами, используемыми для уменьшения размерности при неконтролируемом обучении, являются Анализ главных компонент (PCA) и Сингулярная декомпозиция (SVD).
#
# **Анализ главных компонент (PCA)** – это статистический метод, который создает новые объекты или характеристики данных путем анализа характеристик набора данных. По существу, характеристики данных суммируются или объединяются вместе.
#
# PCA сохраняет корреляции между переменными при создании новых объектов. Основные компоненты, создаваемые методом, представляют собой линейные комбинации исходных переменных, вычисляемые с помощью собственных векторов.
#
# Реализуем данный подход, снизив количество признаков.<br>
# Предварительно напишем функцию, на вход которой будет подаваться количество признаков, до которого мы хотим их сократить, и наши данные, а на выходе будем получать ошибку MAPE стартовой модели. Внутри будет происходить стандартизация данных и PCA.

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


def pca_(features_train, features_valid, n):
    features_train_scaler, features_valid_scaler = scale(features_train, features_valid)
    pca = PCA(n_components = n)
    pca_fit = pca.fit(features_train_scaler)
    features_train_pca = pca_fit.transform(features_train_scaler)
    features_valid_pca = pca_fit.transform(features_valid_scaler)

    res = start_model_result(features_train_pca, target_train, features_valid_pca, target_valid, False)
    return res, features_train_pca, features_valid_pca

# %% [markdown]
# Узнаем, при каком количестве компонент мы получаем наименьшую ошибку.<br>
# Для визуального понимания построим график.

# %%
error_pca = []
steps = range(1, 71)
for i in steps:
    error_pca.append(pca_(features_train_missing, features_valid_missing, i)[0])
    
plt.plot(steps, error_pca, 'b')
plt.ylabel('Ошибка MAPE')
plt.xlabel('Количество компонент')
plt.show()

# %% [markdown]
# Можем видеть, что сжатие до 6 компонент дает наименьший MAPE. При увеличении количества компонент растет и ошибка.<br>
# Зафиксируем результат при 6 компонентах.

# %%
res_pca = pca_(features_train_missing, features_valid_missing, 6)
res_pca
# Out:
# (8.020314188881374,
#  array([[ 1.02350476e+01, -2.59484506e+00, -1.60044152e+01,
#          -7.19549877e-01, -8.71399290e-01, -2.63873043e-01],
#         [-1.07568092e+01, -8.60177675e+00,  1.28004986e+01,
#          -8.72310875e-01, -9.75758148e+00, -4.86329629e-01],
#         [-1.79579453e+01,  2.50177181e+00,  4.47436510e+00,
#          -4.21990005e+00,  2.91196166e+00, -2.45192835e+00],
#         [-1.85157368e+00,  1.46712848e+00, -1.13612997e+01,
#           2.29843221e+00,  1.49264243e+00, -8.69988750e-01],
#         [-1.71490893e+01,  5.25496311e+00, -3.08137660e+00,
#           8.47403456e-01, -2.10850979e+00, -2.53945637e+00],
#         [ 2.20154741e+01, -1.60859698e+01,  1.21712115e+01,
#          -9.81150626e+00,  1.26899452e+01, -7.32705244e+00],
#         [-4.31873452e+01,  2.29440397e+01, -1.44565305e+00,
#           2.82691517e+00,  2.09709530e-01,  2.05904809e-01],
#         [-5.97185496e+00, -1.16464180e+01,  6.66448369e+00,
#           8.48224683e+00, -1.23011161e+01, -6.22555072e+00],
#         [-3.76934040e+00,  1.12473596e+01,  1.50536814e+01,
#          -2.27381046e+01,  5.21569845e+00,  1.01661461e+01],
#         [-3.83806944e+00, -8.13114536e+00,  5.74770846e+00,
#           5.35854467e+00,  2.34010226e+00, -2.19042378e-01],
#         [ 2.26518384e+01, -1.17727058e+01, -1.49530679e+00,
#          -6.90766339e+00, -4.34257780e+00, -8.09410705e+00],
#         [-5.19736048e+00, -5.02044726e+00,  3.09313543e+00,
#           1.03416462e+01, -9.79747055e+00,  4.23587543e-01],
#         [-1.12549984e+01,  2.76940406e+00, -1.41417970e+00,
#           1.42699202e+00, -1.61257825e+00,  5.02023653e+00],
#         [-2.41794878e+00, -1.63402713e+00,  1.29026827e+01,
#          -1.60697246e+01,  3.26032787e+00,  1.96142238e+00],
#         [-2.29835081e+01,  5.37476143e+00, -1.37949919e+00,
#           6.32231185e+00, -4.33430976e+00,  5.82423550e+00],
#         [-2.29366977e+01,  1.70869259e+00,  7.26598338e+00,
#          -1.02023927e+01, -1.57524797e+01, -9.19215773e+00],
#         [ 3.22778441e+01, -2.67391994e+00, -4.60279896e+00,
#          -2.36907782e+01,  8.30893293e+00,  1.42003347e+01],
#         [-6.92850661e-03, -3.30214955e+00, -4.45822174e+00,
#           1.31477740e+01, -3.23691529e+00,  1.70952441e+00],
#         [ 2.09147313e+01, -5.15449451e+00, -9.85106931e+00,
#          -5.77363396e+00, -4.38278553e+00, -8.48286973e+00]]))

# %% [markdown]
# Снизили размах ошибки в условиях одномиллионного товарооборота на 10 тыс. Успех.

# %% [markdown]
# ##### 3.4 Важность признаков
#
# Последний метод, который мы используем для отбора признаков: выявление их важности.
#
# Воспользуемся стартовой моделью на данных, которые мы получили в пункте 1 (features_train_missing).

# %%
model_c = CatBoostRegressor(n_estimators=200,
                      learning_rate=0.01,
                      max_depth=3, 
                      loss_function='Quantile',
                      metric_period=100)
model_c.fit(features_train_missing, target_train)

values = model_c.get_feature_importance(Pool(features_train_missing, label=target_train))
# Out:
# 0:	learn: 0.0684695	total: 22.2ms	remaining: 4.43s
# 100:	learn: 0.0532420	total: 1.81s	remaining: 1.78s
# 199:	learn: 0.0453541	total: 3.58s	remaining: 0us

# %% [markdown]
# Проверим различные пороговые значения для значимости: отсечем данные, которые ниже данного порога и запустим стартовую модель.

# %%
result = []
steps_ = np.linspace(0.1, 1, 10)

for i in steps_:
    features_train_copy = features_train_missing.copy()
    for k in range(len(values)):
        if values[k] < i:
            features_train_copy = features_train_copy.drop([features_train_missing.columns[k]], axis=1)
    
    result.append(start_model_result(features_train_copy, target_train, features_valid, target_valid, False))

    
plt.plot(steps_, result, 'b')
plt.ylabel('Ошибка MAPE')
plt.xlabel('Важность, ниже которой признаки удаляются')
plt.show()

# %% [markdown]
# Можем наблюдать, что при удалении признаков, важность которых ниже 0.5, модель выдает наименьшую ошибку.

# %% [markdown]
# #### 4. Использование различных алгоритмов и настройка их гиперпараметров.

# %% [markdown]
# Мы выяснили, что наименьшую ошибку мы получили после обработки пропусков и сжатия данных методом PCA до 6 компонент.<br>
# Будем использовать эти данные для обучения моделей.

# %%
res, features_train_final, features_valid_final = pca_(features_train_missing, features_valid_missing, 6)

# %% [markdown]
# Найдем ошибку на валидационных данных для следующих алгоритмов обучения:
# 1. Дерево решений
# 2. Случайный лес
# 3. Линейная регрессия
# 4. LGBMRegressor
# 5. CatBoostRegressor
#
# Используем различные гиперпараметры моделей.
#
# Также напишем свой скорер.

# %%
mape_scorer = make_scorer(mean_absolute_percentage_error, greater_is_better = False)

# %% [markdown]
# ##### 4.1 Дерево решений

# %%
# %%time

best_depth = 0
best_tree = None
best_mape = 1000
for depth in range(1, 20):
    model_tree = RandomForestRegressor(random_state = 12345, max_depth = depth)
    model_tree.fit(features_train_final, target_train)
    prediction = model_tree.predict(features_valid_final)
    mape = mean_absolute_percentage_error(target_valid, prediction)
    if mape < best_mape:
        best_mape = mape
        best_tree = model_tree
        best_depth = depth

print("MAPE:", best_mape, 'Глубина:', best_depth)
# Out:
# MAPE: 8.451683351039161 Глубина: 6
# CPU times: user 2.44 s, sys: 12 ms, total: 2.46 s
# Wall time: 2.46 s

# %% [markdown]
# ##### 4.2 Случайный лес

# %%
# %%time

best_est = 0
best_depth_f = 0
best_forest = None
best_mape_f = 1000
for est in range(5, 40, 5):
    for depth in range(1, 14):
        model_forest = RandomForestRegressor(random_state = 12345, max_depth = depth, n_estimators = est)
        model_forest.fit(features_train_final, target_train)
        prediction = model_forest.predict(features_valid_final)
        mape = mean_absolute_percentage_error(target_valid, prediction)
        if mape < best_mape_f:
            best_mape_f = mape
            best_forest = model_forest
            best_est = est
            best_depth_f = depth

print("MAPE:", best_mape_f, 'Глубина:', best_depth_f, ', Количество деревьев:', best_est)
# Out:
# MAPE: 7.18785451183609 Глубина: 4 , Количество деревьев: 5
# CPU times: user 2.41 s, sys: 19.9 ms, total: 2.43 s
# Wall time: 2.43 s

# %% [markdown]
# ##### 4.3 Линейная регрессия

# %%
# %%time

model_linear = LinearRegression()
model_linear.fit(features_train_final, target_train)

prediction = model_linear.predict(features_valid_final)
print("MAPE:", mean_absolute_percentage_error(target_valid, prediction))
# Out:
# MAPE: 8.817643304043912
# CPU times: user 2.63 ms, sys: 0 ns, total: 2.63 ms
# Wall time: 2.34 ms

# %% [markdown]
# ##### 4.4 LGBMRegressor

# %%
# %%time

model_lgbm_ = LGBMRegressor(random_state=12345)

param = {'n_estimators': range(5, 100, 5),
        'num_leaves': range(1, 30, 3)}

grid_lgbm = GridSearchCV(model_lgbm_, param, cv=5, scoring = mape_scorer)
grid_lgbm.fit(features_train_final, target_train)
print(grid_lgbm.best_estimator_)
# Out:
# LGBMRegressor(n_estimators=70, num_leaves=4, random_state=12345)
# CPU times: user 24.3 s, sys: 268 ms, total: 24.6 s
# Wall time: 6.4 s
# /home/matu/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 95 fits failed out of a total of 950.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 95 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/matu/.local/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/matu/.local/lib/python3.8/site-packages/lightgbm/sklearn.py", line 895, in fit
#     super().fit(X, y, sample_weight=sample_weight, init_score=init_score,
#   File "/home/matu/.local/lib/python3.8/site-packages/lightgbm/sklearn.py", line 748, in fit
#     self._Booster = train(
#   File "/home/matu/.local/lib/python3.8/site-packages/lightgbm/engine.py", line 271, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "
#   -9.8107026   -9.8107026   -9.8107026   -9.8107026   -9.8107026
#           nan  -9.8580309   -9.8580309   -9.8580309   -9.8580309
#   -9.8580309   -9.8580309   -9.8580309   -9.8580309   -9.8580309 ]
#   warnings.warn(

# %%
model_lgbm = LGBMRegressor(**grid_lgbm.best_params_, random_state=12345)
model_lgbm.fit(features_train_final, target_train)
prediction = model_lgbm.predict(features_valid_final)
print("MAPE:", mean_absolute_percentage_error(target_valid, prediction))
# Out:
# MAPE: 8.900029052252805

# %% [markdown]
# ##### 4.5 CatBoostRegressor

# %%
# %%time

model_cat = CatBoostRegressor(random_state = 12345,
                              loss_function='MAPE', #'Quantile'
                              logging_level='Silent',
                              metric_period=100,
                              learning_rate=0.001,
                              n_estimators=5)

param = {'l2_leaf_reg': [1, 9, 12, 15],
        'learning_rate': [0.0001, 0.001, 0.01, 0.1],
        'depth': [1,2,3,4]}

grid = model_cat.grid_search(param, X=features_train_final, y=target_train)
# Out:
# 0:	loss: 0.9995130	best: 0.9995130 (0)	total: 72.7ms	remaining: 4.58s
# 1:	loss: 0.9951388	best: 0.9951388 (1)	total: 75.5ms	remaining: 2.34s
# 2:	loss: 0.9522451	best: 0.9522451 (2)	total: 77.2ms	remaining: 1.57s
# 3:	loss: 0.5987681	best: 0.5987681 (3)	total: 78.4ms	remaining: 1.18s
# 4:	loss: 0.9995130	best: 0.5987681 (3)	total: 79.4ms	remaining: 937ms
# 5:	loss: 0.9951388	best: 0.5987681 (3)	total: 80.4ms	remaining: 777ms
# 6:	loss: 0.9522451	best: 0.5987681 (3)	total: 81.5ms	remaining: 663ms
# 7:	loss: 0.5987681	best: 0.5987681 (3)	total: 82.5ms	remaining: 577ms
# 8:	loss: 0.9995130	best: 0.5987681 (3)	total: 83.5ms	remaining: 510ms
# 9:	loss: 0.9951388	best: 0.5987681 (3)	total: 84.5ms	remaining: 456ms
# 10:	loss: 0.9522451	best: 0.5987681 (3)	total: 85.5ms	remaining: 412ms
# 11:	loss: 0.5987681	best: 0.5987681 (3)	total: 86.6ms	remaining: 375ms
# 12:	loss: 0.9995130	best: 0.5987681 (3)	total: 87.7ms	remaining: 344ms
# 13:	loss: 0.9951388	best: 0.5987681 (3)	total: 88.9ms	remaining: 318ms
# 14:	loss: 0.9522451	best: 0.5987681 (3)	total: 90ms	remaining: 294ms
# 15:	loss: 0.5987681	best: 0.5987681 (3)	total: 91.1ms	remaining: 273ms
# 16:	loss: 0.9995159	best: 0.5987681 (3)	total: 92.3ms	remaining: 255ms
# 17:	loss: 0.9951679	best: 0.5987681 (3)	total: 93.7ms	remaining: 239ms
# 18:	loss: 0.9525468	best: 0.5987681 (3)	total: 95ms	remaining: 225ms
# 19:	loss: 0.6015848	best: 0.5987681 (3)	total: 96.3ms	remaining: 212ms
# 20:	loss: 0.9995142	best: 0.5987681 (3)	total: 97.7ms	remaining: 200ms
# 21:	loss: 0.9951506	best: 0.5987681 (3)	total: 99ms	remaining: 189ms
# 22:	loss: 0.9523743	best: 0.5987681 (3)	total: 100ms	remaining: 179ms
# 57:	loss: 0.9955230	best: 0.5984957 (31)	total: 170ms	remaining: 17.6ms
# 58:	loss: 0.9560788	best: 0.5984957 (31)	total: 172ms	remaining: 14.6ms
# 59:	loss: 0.6358471	best: 0.5984957 (31)	total: 177ms	remaining: 11.8ms
# 60:	loss: 0.9995524	best: 0.5984957 (31)	total: 185ms	remaining: 9.11ms
# 61:	loss: 0.9955323	best: 0.5984957 (31)	total: 188ms	remaining: 6.08ms
# 62:	loss: 0.9561746	best: 0.5984957 (31)	total: 193ms	remaining: 3.06ms
# 63:	loss: 0.6339006	best: 0.5984957 (31)	total: 196ms	remaining: 0us
# Estimating final quality...
# CPU times: user 372 ms, sys: 56.8 ms, total: 429 ms
# Wall time: 699 ms

# %%
model_cat = CatBoostRegressor(random_state=12345, verbose=False, **grid['params'])
model_cat.fit(features_train_final, target_train)
prediction = model_cat.predict(features_valid_final)
print("MAPE:", mean_absolute_percentage_error(target_valid, prediction))
# Out:
# MAPE: 6.181012554494513

# %% [markdown]
# **Получили MAPE равную 6.18**<br>
# Успешное завершение работы. Начальная ошибка стартовой модели на не предобработанных данных была 8.69<br>
# После обработки пропусков и сжатия данных методом PCA до 6 компонент мы добились показателя ошибки 6.18<br>
# Разница в ошибке 2.5<br> Что на бизнес языке звучит следующим образом: учитывая обработанные данные и построенную модель оценки объема товарооборота, ошибка в одномиллионном масштабе с 87 тыс. рублей снизилась до 62 тыс. рублей. А размах ошибки снизился в 1.4 раза (8.69 / 6.18)
#
# Было:
# $$
# 1млн ± 87тыс.рублей
# $$
# Стало:
# $$
# 1млн ± 62тыс.рублей
# $$
# <br>
# <br>
# Теперь давайте обработаем наши тестовые данные, аналогично тем, на которых мы обучались, и обучим модель уже на совмещенной тренировочной и валидационной выборке (есть основания предполагать, что совмещенная, а соответственно бОльшая выборка в условиях малого количества объектов даст лучший результат). Сделаем прогноз на тесте и сохраним в приложенной форме.
#
# Порядок действий:
# - удалить столбцы из тестовой выборки, которые не входят в features_missing (напомню, features_missing - это все признаки в уже совмещенной выборке (train+valid), прошедшие обработку пропусков и удаление некоторых фич)
# - остальные пропуски заполнить нулями
# - применить StandardScaler на features_missing и трансформировать на test
# - аналогично поступить с PCA c 6 компонентами
# - обучиться на features_missing после обработки и PCA
# - сделать прогноз на тесте

# %%
features_test_ = features_test.copy()

for i in features_test.columns:
    if i not in features_missing.columns:
        features_test_ = features_test_.drop([i], axis=1)
features_test_ = features_test_.fillna(0)

feature_train_valid_scaled, feature_test_scaled = scale(features_missing, features_test_)
pca = PCA(n_components = 6)
pca_fit = pca.fit(feature_train_valid_scaled)
feature_train_valid_pca = pca_fit.transform(feature_train_valid_scaled)
feature_test_pca = pca_fit.transform(feature_test_scaled)

model_cat.fit(feature_train_valid_pca, target)
prediction = model_cat.predict(feature_test_pca)
form['target predicted'] = prediction
form
# Out:
#     id  target predicted
# 0    3          1.459081
# 1   25          1.340457
# 2   55          1.374216
# 3   69          1.520891
# 4  109          1.390150
# 5  112          1.350969
# 6  117          1.423728
# 7  126          1.273843
# 8  144          1.559108
# 9  145          1.441783
